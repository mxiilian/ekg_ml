# %%
# 1. Kaggle installieren (falls noch nicht installiert)
# !pip install kaggle
# 2. API-Token hochladen
# Lade deine kaggle.json von kaggle.com/account herunter
# Dann in Jupyter:
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# 3. Competition-Daten herunterladen
# !kaggle competitions download -c physionet-ecg-image-digitization
